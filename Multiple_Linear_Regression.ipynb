# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakhimovvv/Regression/blob/main/Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_LR.csv', index_col=0)
df.head(10)
# Out:
#         district  rooms  size  level  max_levels    price
# 0   Юнусабадский      3  57.0      4           4  52000.0
# 1  Яккасарайский      2  52.0      4           5  56000.0
# 2   Чиланзарский      2  42.0      4           4  37000.0
# 3   Чиланзарский      3  65.0      1           4  49500.0
# 4   Чиланзарский      3  70.0      3           5  55000.0
# 5   Чиланзарский      1  28.0      1           4  25500.0
# 6   Чиланзарский      1  30.0      2           4  21200.0
# 7  Яккасарайский      2  32.0      5           5  20000.0
# 8    Учтепинский      2  51.0      3           4  26200.0
# 9   Чиланзарский      1  30.0      1           4  22200.0

# %%
housing = df[df.district=='Чиланзарский']
housing.head()
# Out:
#        district  rooms  size  level  max_levels    price
# 2  Чиланзарский      2  42.0      4           4  37000.0
# 3  Чиланзарский      3  65.0      1           4  49500.0
# 4  Чиланзарский      3  70.0      3           5  55000.0
# 5  Чиланзарский      1  28.0      1           4  25500.0
# 6  Чиланзарский      1  30.0      2           4  21200.0

# %% [markdown]
# train//test

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.1, random_state=42)

# %% [markdown]
# ML

# %%
from sklearn import linear_model
MLR_model = linear_model.LinearRegression()
x_train = np.asanyarray(train_set[['size', 'rooms','level']])
y_train = np.asanyarray(train_set[['price']])
MLR_model.fit(x_train, y_train)
print('Coefficients: ', MLR_model.coef_)
print('Intercept: ', MLR_model.intercept_)
# Out:
# Coefficients:  [[  871.08966085 -3144.72602382 -1477.7538114 ]]
# Intercept:  [3811.13853016]

# %%
sns.pairplot(df[['size', 'rooms','level','price']])

# %% [markdown]
# Modelni baholash

# %%
x_test = np.asanyarray(test_set[['size', 'rooms','level']])
y_test = np.asanyarray(test_set[['price']])
y_pred = MLR_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print('MAE: ', mean_absolute_error(y_test, y_pred))
print('MSE: ', mean_squared_error(y_test, y_pred))
# Out:
# MAE:  7401.997922334466
# MSE:  149987343.93321285
